# %%
import pandas as pd

path = "/home/szxie/storage/lerobot/data/baked/2025-11-12_joint6/data/chunk-000/file_000.parquet"

df = pd.read_parquet(path)

# print(df)
# print(df.columns)
print(len(df))
# Out:
# 37993

# %%
df.head(536).to_csv("preview_536.txt", index=False)

# %%
import pandas as pd

paths = [
    "/home/szxie/storage/lerobot/data/baked/2025-11-12_joint6/meta/tasks.parquet",
    "/home/szxie/storage/lerobot/data/baked/2025-11-12/meta/tasks.parquet",
]

for p in paths:
    print("=" * 80)
    print(f"Reading: {p}")
    try:
        df = pd.read_parquet(p)
        print(df)
    except Exception as e:
        print(f"Error reading {p}: {e}")
